# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import roc_auc_score

pd.options.display.max_columns = 100
pd.options.display.max_rows = 150

# %%
df_train = pd.read_csv("data/competition_data/train.csv")
df_train = df_train.sample(frac=1).reset_index(drop=True)

df_test = pd.read_csv("data/competition_data/test.csv")

df_train
# Out:
#             id  bin_0  bin_1  bin_2 bin_3 bin_4  nom_0      nom_1    nom_2  \
# 0       256403      0      0      0     T     Y    Red       Star     Lion
# 1        75557      0      0      0     T     Y    Red   Triangle     Lion
# 2       267915      0      0      1     F     N  Green     Circle      Dog
# 3       106685      0      1      1     T     Y    Red  Trapezoid    Snake
# 4       281526      0      0      1     F     Y   Blue     Square  Axolotl
# ...        ...    ...    ...    ...   ...   ...    ...        ...      ...
# 299995  292532      0      1      0     F     N  Green     Square     Lion
# 299996  233649      0      0      0     T     N    Red     Square      Cat
# 299997  188741      0      0      0     T     N    Red  Trapezoid  Hamster
# 299998   35881      0      0      0     F     Y    Red     Square      Cat
# 299999  247777      0      0      1     T     N    Red  Trapezoid      Dog
#
#              nom_3    nom_4      nom_5      nom_6      nom_7      nom_8  \
# 0           Russia     Oboe  416a8f3ab  e3396fbd5  5ad7da858  4329a8c91
# 1            India  Bassoon  8266050c6  d213f48ed  fa311a2a3  551be7857
# 2            India  Bassoon  0b3bec656  c8436c277  cb9bbed08  bb215fb49
# 3           Canada     Oboe  c0534106d  1611d2b45  d888dabd2  f58eea518
# 4           Russia     Oboe  b97f51ac4  bd47c2363  b9b5e2958  203ed591a
# ...            ...      ...        ...        ...        ...        ...
# 299995  Costa Rica  Bassoon  d1b1709e8  c9eedfbc2  59fe57a1b  eb2dc547b
# 299996     Finland    Piano  475e79160  1b36c0b8c  aa148acce  51be79e62
# 299997  Costa Rica    Piano  76be0b8b1  73dd803d0  b0fad10d7  4d70170c4
# 299998     Finland    Piano  3263bdce5  4daee3baf  d18fe040f  b13166170
# 299999      Russia    Piano  e6f45aa26  487c32dfa  3b679e531  8c798dfeb
#
#             nom_9  ord_0        ord_1        ord_2 ord_3 ord_4 ord_5  day  \
# 0       9fddc642c      1       Expert     Lava Hot     k     W    ut    2
# 1       b0406edeb      2       Novice     Freezing     k     V    QM    2
# 2       0e85ebce3      2       Novice  Boiling Hot     i     I    aO    7
# 3       ba877ef51      1       Novice     Freezing     a     L    sY    2
# 4       244f3d156      3       Novice  Boiling Hot     j     K    sV    4
# ...           ...    ...          ...          ...   ...   ...   ...  ...
# 299995  817e2c7b5      1       Novice     Freezing     l     P    CM    1
# 299996  e7dc16f7e      2  Grandmaster     Lava Hot     k     T    yc    3
# 299997  67fe1445f      1       Novice  Boiling Hot     h     R    RL    4
# 299998  9c58f3be5      3       Master     Freezing     a     K    be    2
# 299999  e65e3caff      1       Novice     Freezing     j     V    Wv    3
#
#         month  target
# 0          12       1
# 1           9       1
# 2           1       0
# 3          11       0
# 4          12       1
# ...       ...     ...
# 299995      3       0
# 299996     12       1
# 299997     11       0
# 299998      1       0
# 299999      3       0
#
# [300000 rows x 25 columns]

# %%
y_train = df_train["target"]

y_train
# Out:
# 0         1
# 1         1
# 2         0
# 3         0
# 4         1
#          ..
# 299995    0
# 299996    1
# 299997    0
# 299998    0
# 299999    0
# Name: target, Length: 300000, dtype: int64

# %%
def process_features(df):
    df_out = df.copy()
    
    # binary features to 0, 1
    df_out["bin_3"] = df_out["bin_3"].map({"T": 1, "F": 0})
    df_out["bin_4"] = df_out["bin_4"].map({"Y": 1, "N": 0})

    # ordinal features to int
    for field in ["ord_1", "ord_2", "ord_3", "ord_4", "ord_5"]:
        df[field] = pd.Categorical(df[field])
        df_out[field] = df[field].cat.codes
        
    # nominal features to int (same as for ordinal, but let's separate to keep us some options)
    for field in ['nom_0', 'nom_1', 'nom_2', 'nom_3', 'nom_4', 'nom_5', 'nom_6', 'nom_7', 'nom_8', 'nom_9']:
        df[field] = pd.Categorical(df[field])
        df_out[field] = df[field].cat.codes
        
    return df_out


df_train_processed = process_features(df_train)

del df_train_processed["target"]
del df_train_processed["id"]

df_train_processed
# Out:
#         bin_0  bin_1  bin_2  bin_3  bin_4  nom_0  nom_1  nom_2  nom_3  nom_4  \
# 0           0      0      0      1      1      2      3      4      5      1
# 1           0      0      0      1      1      2      5      4      4      0
# 2           0      0      1      0      0      1      0      2      4      0
# 3           0      1      1      1      1      2      4      5      0      1
# 4           0      0      1      0      1      0      2      0      5      1
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 299995      0      1      0      0      0      1      2      4      2      0
# 299996      0      0      0      1      0      2      2      1      3      2
# 299997      0      0      0      1      0      2      4      3      2      2
# 299998      0      0      0      0      1      2      2      1      3      2
# 299999      0      0      1      1      0      2      4      2      5      2
#
#         nom_5  nom_6  nom_7  nom_8  nom_9  ord_0  ord_1  ord_2  ord_3  ord_4  \
# 0          59    461    419    564   7406      1      1      4     10     22
# 1         120    419   1186    727   8182      2      4      2     10     21
# 2          11    399    958   1615    684      2      4      0      8      8
# 3         170     40   1031   2123   8652      1      4      2      0     11
# 4         163    379    849    303   1704      3      4      0      9     10
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 299995    176    401    413   2029   6009      1      4      2     11     15
# 299996     67     54    786    696  10858      2      2      4     10     19
# 299997    109    231    819    654   4861      1      4      0      7     17
# 299998     44    159    989   1527   7234      3      3      2      0     10
# 299999    196    146    259   1219  10781      1      4      2      9     21
#
#         ord_5  day  month
# 0         178    2     12
# 1          55    2      9
# 2          89    7      1
# 3         168    2     11
# 4         167    4     12
# ...       ...  ...    ...
# 299995      9    1      3
# 299996    190    3     12
# 299997     60    4     11
# 299998     95    2      1
# 299999     76    3      3
#
# [300000 rows x 23 columns]

# %%
model = AdaBoostClassifier(
    base_estimator=DecisionTreeClassifier(
        criterion="entropy",
        min_samples_leaf = 600,
        min_samples_split = 1000,
        max_depth = 3
    ),
    n_estimators=30
)

i = df_train_processed.shape[0]
df_train_processed1 = df_train_processed.copy()[:i // 2]
df_train_processed2 = df_train_processed.copy()[i // 2:]
y_train1=y_train[:i // 2]
y_train2=y_train[i // 2:]

def fit_and_score(model, df_train, y_train, df_test, y_test):
    model = model.fit(df_train, y_train)
    
    y_score_train = [s[1] for s in model.predict_proba(df_train)]
    y_score_test = [s[1] for s in model.predict_proba(df_test)]

    print(f"""
        Score on training set: {roc_auc_score(y_true=y_train, y_score=y_score_train)}
        Score on test set: {roc_auc_score(y_true=y_test, y_score=y_score_test)}
    """)
    
    return model

model = fit_and_score(model, df_train_processed1, y_train1, df_train_processed2, y_train2)
# Out:
#         Score on training set: 0.7711043196454681
#         Score on test set: 0.7626247192834823

# %%
"""Looks good, let'S submit"""



df_test_processed = process_features(df_test)

del df_test_processed["id"]

y_pred = [x[1] for x in model.predict_proba(df_test_processed)]


submission = pd.read_csv("data/competition_data/sample_submission.csv")

submission["target"] = y_pred

submission.to_csv("data/submissions/submission_adaboost.csv", header=True, index=False)

# %%
submission[:100]
# Out:
#         id    target
# 0   300000  0.490604
# 1   300001  0.500727
# 2   300002  0.485138
# 3   300003  0.499107
# 4   300004  0.511549
# 5   300005  0.492554
# 6   300006  0.499121
# 7   300007  0.484965
# 8   300008  0.500669
# 9   300009  0.501453
# 10  300010  0.489902
# 11  300011  0.496069
# 12  300012  0.496478
# 13  300013  0.493630
# 14  300014  0.487081
# 15  300015  0.501216
# 16  300016  0.484741
# 17  300017  0.508456
# 18  300018  0.500504
# 19  300019  0.506332
# 20  300020  0.498487
# 21  300021  0.501840
# 22  300022  0.483021
# 23  300023  0.471555
# 24  300024  0.493088
# 25  300025  0.472765
# 26  300026  0.483344
# 27  300027  0.484634
# 28  300028  0.482256
# 29  300029  0.503654
# 30  300030  0.486673
# 31  300031  0.490985
# 32  300032  0.487599
# 33  300033  0.480495
# 34  300034  0.476627
# 35  300035  0.488912
# 36  300036  0.493050
# 37  300037  0.483556
# 38  300038  0.503642
# 39  300039  0.513548
# 40  300040  0.487258
# 41  300041  0.485304
# 42  300042  0.482288
# 43  300043  0.486276
# 44  300044  0.491959
# 45  300045  0.490993
# 46  300046  0.479663
# 47  300047  0.495082
# 48  300048  0.503756
# 49  300049  0.484977
# 50  300050  0.484725
# 51  300051  0.504767
# 52  300052  0.493044
# 53  300053  0.475092
# 54  300054  0.504454
# 55  300055  0.488047
# 56  300056  0.482496
# 57  300057  0.475393
# 58  300058  0.497572
# 59  300059  0.495960
# 60  300060  0.488765
# 61  300061  0.506799
# 62  300062  0.494373
# 63  300063  0.502924
# 64  300064  0.472888
# 65  300065  0.504963
# 66  300066  0.493336
# 67  300067  0.496307
# 68  300068  0.501103
# 69  300069  0.508895
# 70  300070  0.501651
# 71  300071  0.494609
# 72  300072  0.490690
# 73  300073  0.491152
# 74  300074  0.481915
# 75  300075  0.490213
# 76  300076  0.498996
# 77  300077  0.489903
# 78  300078  0.496896
# 79  300079  0.487688
# 80  300080  0.482094
# 81  300081  0.490358
# 82  300082  0.520209
# 83  300083  0.486207
# 84  300084  0.496261
# 85  300085  0.486293
# 86  300086  0.499271
# 87  300087  0.490260
# 88  300088  0.492789
# 89  300089  0.486893
# 90  300090  0.498271
# 91  300091  0.501558
# 92  300092  0.490931
# 93  300093  0.482772
# 94  300094  0.495831
# 95  300095  0.496115
# 96  300096  0.491342
# 97  300097  0.499366
# 98  300098  0.481999
# 99  300099  0.484514

# %%
"""kaggle score: ~0.765"""
# Out:
# 'kaggle score: ~0.765'
