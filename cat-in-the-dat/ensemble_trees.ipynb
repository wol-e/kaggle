# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import roc_auc_score

pd.options.display.max_columns = 100
pd.options.display.max_rows = 150

# %%
df_train = pd.read_csv("data/competition_data/train.csv")
df_train = df_train.sample(frac=1).reset_index(drop=True)

df_test = pd.read_csv("data/competition_data/test.csv")

df_train
# Out:
#             id  bin_0  bin_1  bin_2 bin_3 bin_4  nom_0      nom_1    nom_2  \
# 0       295587      0      1      1     T     Y  Green  Trapezoid    Snake
# 1       296800      0      0      0     T     Y  Green    Polygon      Cat
# 2       191133      0      0      0     T     Y   Blue     Square    Snake
# 3       221013      1      0      1     T     N    Red    Polygon     Lion
# 4       281647      0      0      0     T     N   Blue     Circle      Cat
# ...        ...    ...    ...    ...   ...   ...    ...        ...      ...
# 299995  103530      0      0      1     T     N    Red  Trapezoid    Snake
# 299996  268822      0      0      0     F     N  Green  Trapezoid    Snake
# 299997  153713      0      0      1     F     N  Green  Trapezoid      Cat
# 299998   90880      0      0      0     T     N   Blue     Square     Lion
# 299999   74938      1      1      1     T     N  Green       Star  Hamster
#
#           nom_3     nom_4      nom_5      nom_6      nom_7      nom_8  \
# 0        Russia  Theremin  2cc9e16b9  c36cea1f7  352282217  d5b52c3c3
# 1         India      Oboe  5b1a9f841  144279ac1  4cd460e06  382cf7e87
# 2        Russia   Bassoon  6fec43dd8  73dd803d0  01d32ba52  e601670bb
# 3        Canada     Piano  488406659  113deddc9  a1e0839a7  99b33644d
# 4        Russia   Bassoon  91a20b464  3afd0489b  3642c70d4  fbd2354a7
# ...         ...       ...        ...        ...        ...        ...
# 299995   Canada      Oboe  5a466e166  7d8bc814a  d02a6b0ba  6b972b4e6
# 299996   Canada     Piano  a93b89fc9  2ed5a94b0  bb8e9193e  b19bb1c28
# 299997   Russia      Oboe  6a2269152  39981f199  c92eb0903  6196dcb02
# 299998  Finland  Theremin  f2d59cf51  32b4b12b1  89f4255e4  3691833c1
# 299999   Russia     Piano  05950689f  32db19124  6065c72b8  6e23e1067
#
#             nom_9  ord_0        ord_1        ord_2 ord_3 ord_4 ord_5  day  \
# 0       4ef405b94      1       Novice          Hot     i     H    Nf    1
# 1       05be0a334      3       Novice     Lava Hot     f     Z    dP    5
# 2       7188e7e3e      1  Grandmaster     Freezing     i     V    Bn    4
# 3       23bc7322c      2       Master     Lava Hot     f     P    Ed    3
# 4       2883f1fde      2       Novice     Lava Hot     k     I    cA    2
# ...           ...    ...          ...          ...   ...   ...   ...  ...
# 299995  401c2455c      2       Novice  Boiling Hot     d     F    ex    3
# 299996  ec3116ee6      1  Grandmaster         Cold     a     R    Jc    4
# 299997  e2a1ab525      1       Novice     Lava Hot     h     F    MV    1
# 299998  b29127fef      1       Master         Warm     j     Z    GJ    3
# 299999  d1a119dd4      1       Master  Boiling Hot     g     P    qK    3
#
#         month  target
# 0          11       0
# 1           9       0
# 2           7       0
# 3           2       1
# 4          12       0
# ...       ...     ...
# 299995     10       1
# 299996      2       0
# 299997      8       0
# 299998      3       0
# 299999     11       1
#
# [300000 rows x 25 columns]

# %%
y_train = df_train["target"]

y_train
# Out:
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0
#          ..
# 299995    1
# 299996    0
# 299997    0
# 299998    0
# 299999    1
# Name: target, Length: 300000, dtype: int64

# %%
def process_features(df):
    df_out = df.copy()
    
    # binary features to 0, 1
    df_out["bin_3"] = df_out["bin_3"].map({"T": 1, "F": 0})
    df_out["bin_4"] = df_out["bin_4"].map({"Y": 1, "N": 0})

    # ordinal features to int
    for field in ["ord_1", "ord_2", "ord_3", "ord_4", "ord_5"]:
        df[field] = pd.Categorical(df[field])
        df_out[field] = df[field].cat.codes
        
    # nominal features to int (same as for ordinal, but let's separate to keep us some options)
    for field in ['nom_0', 'nom_1', 'nom_2', 'nom_3', 'nom_4', 'nom_5', 'nom_6', 'nom_7', 'nom_8', 'nom_9']:
        df[field] = pd.Categorical(df[field])
        df_out[field] = df[field].cat.codes
        
    return df_out


df_train_processed = process_features(df_train)

del df_train_processed["target"]
del df_train_processed["id"]

df_train_processed
# Out:
#         bin_0  bin_1  bin_2  bin_3  bin_4  nom_0  nom_1  nom_2  nom_3  nom_4  \
# 0           0      1      1      1      1      1      4      5      5      3
# 1           0      0      0      1      1      1      1      1      4      1
# 2           0      0      0      1      1      0      2      5      5      0
# 3           1      0      1      1      0      2      1      4      0      2
# 4           0      0      0      1      0      0      0      1      5      0
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 299995      0      0      1      1      0      2      4      5      0      1
# 299996      0      0      0      0      0      1      4      5      0      2
# 299997      0      0      1      0      0      1      4      1      5      1
# 299998      0      0      0      1      0      0      2      4      3      3
# 299999      1      1      1      1      0      1      3      3      5      2
#
#         nom_5  nom_6  nom_7  nom_8  nom_9  ord_0  ord_1  ord_2  ord_3  ord_4  \
# 0          37    392    229   1852   3677      1      4      3      8      7
# 1          91     34    335    475    292      3      4      4      5     25
# 2         103    231     10   1987   5287      1      2      2      8     21
# 3          70     28    741   1329   1678      2      3      4      5     15
# 4         133    122    234   2178   1902      2      4      4     10      8
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 299995     88    250    980    933   2988      2      4      0      3      5
# 299996    152     99    859   1530  11067      1      2      1      0     17
# 299997     99    118    943    851  10596      1      4      4      7      5
# 299998    211    106    634    467   8294      1      3      5      9     25
# 299999      2    108    446    960   9769      1      3      0      6     15
#
#         ord_5  day  month
# 0          46    1     11
# 1         105    5      9
# 2           7    4      7
# 3          17    3      2
# 4          96    2     12
# ...       ...  ...    ...
# 299995    114    3     10
# 299996     31    4      2
# 299997     41    1      8
# 299998     24    3      3
# 299999    157    3     11
#
# [300000 rows x 23 columns]

# %% [markdown]
# # Adaboost

# %%
model = AdaBoostClassifier(
    base_estimator=DecisionTreeClassifier(
        criterion="entropy",
        min_samples_leaf = 600,
        min_samples_split = 1000,
        max_depth = 3
    ),
    n_estimators=30
)

i = df_train_processed.shape[0]
df_train_processed1 = df_train_processed.copy()[:i // 2]
df_train_processed2 = df_train_processed.copy()[i // 2:]
y_train1=y_train[:i // 2]
y_train2=y_train[i // 2:]

def fit_and_score(model, df_train, y_train, df_test, y_test):
    model = model.fit(df_train, y_train)
    
    y_score_train = [s[1] for s in model.predict_proba(df_train)]
    y_score_test = [s[1] for s in model.predict_proba(df_test)]

    print(f"""
        Score on training set: {roc_auc_score(y_true=y_train, y_score=y_score_train)}
        Score on test set: {roc_auc_score(y_true=y_test, y_score=y_score_test)}
    """)
    
    return model

model = fit_and_score(model, df_train_processed1, y_train1, df_train_processed2, y_train2)
# Out:
#         Score on training set: 0.7685105166989699
#         Score on test set: 0.7634993178224911

# %%
"""Looks good, let's submit"""

df_test_processed = process_features(df_test)

del df_test_processed["id"]

y_pred = [x[1] for x in model.predict_proba(df_test_processed)]


submission = pd.read_csv("data/competition_data/sample_submission.csv")

submission["target"] = y_pred

submission.to_csv("data/submissions/submission_adaboost.csv", header=True, index=False)

# %%
submission[:100]
# Out:
#         id    target
# 0   300000  0.490941
# 1   300001  0.499982
# 2   300002  0.489907
# 3   300003  0.492661
# 4   300004  0.512394
# 5   300005  0.494660
# 6   300006  0.504606
# 7   300007  0.481701
# 8   300008  0.499878
# 9   300009  0.505316
# 10  300010  0.493078
# 11  300011  0.497796
# 12  300012  0.499004
# 13  300013  0.500519
# 14  300014  0.492440
# 15  300015  0.503272
# 16  300016  0.488504
# 17  300017  0.509767
# 18  300018  0.496690
# 19  300019  0.504280
# 20  300020  0.491560
# 21  300021  0.496010
# 22  300022  0.482996
# 23  300023  0.470098
# 24  300024  0.492251
# 25  300025  0.473732
# 26  300026  0.478333
# 27  300027  0.478240
# 28  300028  0.478383
# 29  300029  0.505272
# 30  300030  0.486586
# 31  300031  0.493818
# 32  300032  0.486832
# 33  300033  0.484620
# 34  300034  0.482288
# 35  300035  0.490232
# 36  300036  0.493745
# 37  300037  0.481546
# 38  300038  0.493453
# 39  300039  0.511413
# 40  300040  0.487290
# 41  300041  0.484064
# 42  300042  0.483323
# 43  300043  0.488647
# 44  300044  0.492992
# 45  300045  0.486462
# 46  300046  0.476515
# 47  300047  0.502342
# 48  300048  0.503238
# 49  300049  0.488526
# 50  300050  0.482799
# 51  300051  0.503953
# 52  300052  0.492172
# 53  300053  0.476942
# 54  300054  0.507119
# 55  300055  0.484655
# 56  300056  0.482292
# 57  300057  0.480501
# 58  300058  0.498035
# 59  300059  0.496905
# 60  300060  0.486865
# 61  300061  0.504290
# 62  300062  0.497384
# 63  300063  0.510321
# 64  300064  0.476379
# 65  300065  0.499986
# 66  300066  0.490933
# 67  300067  0.493925
# 68  300068  0.501821
# 69  300069  0.511407
# 70  300070  0.500301
# 71  300071  0.494011
# 72  300072  0.482982
# 73  300073  0.491068
# 74  300074  0.483300
# 75  300075  0.492537
# 76  300076  0.494004
# 77  300077  0.490064
# 78  300078  0.497685
# 79  300079  0.485927
# 80  300080  0.473631
# 81  300081  0.489518
# 82  300082  0.519423
# 83  300083  0.483784
# 84  300084  0.497023
# 85  300085  0.488601
# 86  300086  0.499144
# 87  300087  0.491786
# 88  300088  0.495433
# 89  300089  0.480768
# 90  300090  0.492350
# 91  300091  0.497550
# 92  300092  0.487370
# 93  300093  0.481238
# 94  300094  0.498834
# 95  300095  0.492611
# 96  300096  0.494617
# 97  300097  0.501099
# 98  300098  0.478365
# 99  300099  0.483493

# %%
"""kaggle score: ~0.765"""
# Out:
# 'kaggle score: ~0.765'

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier(
    base_estimator=DecisionTreeClassifier(
        criterion="entropy",
        min_samples_leaf = 1,
        min_samples_split = 1,
        max_depth = 10
    ),
    n_estimators=50,
    eval_metric='auc' # is this accurate for roc auc?
)

model = fit_and_score(model, df_train_processed1, y_train1, df_train_processed2, y_train2)
# Out:
# /home/wolle/miniconda3/envs/data_science/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [09:43:18] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1607604574104/work/src/learner.cc:541:
# Parameters: { base_estimator } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
#
#         Score on training set: 0.8048875240385385
#         Score on test set: 0.7632805535795706

# %%
"""Appears comaprable in resutl to AdaBoost, let's not submit"""
# Out:
# "Appears comaprable in resutl to AdaBoost, let's not submit"
