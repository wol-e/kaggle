# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# '/home/wolfgang/git/kaggle/g_research_crypto_forecasting/notebooks'

# %%
pd.options.display.max_columns=100
assets = pd.read_csv("../data/raw/asset_details.csv")
assets
# Out:
#     Asset_ID    Weight        Asset_Name
# 0          2  2.397895      Bitcoin Cash
# 1          0  4.304065      Binance Coin
# 2          1  6.779922           Bitcoin
# 3          5  1.386294            EOS.IO
# 4          7  2.079442  Ethereum Classic
# 5          6  5.894403          Ethereum
# 6          9  2.397895          Litecoin
# 7         11  1.609438            Monero
# 8         13  1.791759              TRON
# 9         12  2.079442           Stellar
# 10         3  4.406719           Cardano
# 11         8  1.098612              IOTA
# 12        10  1.098612             Maker
# 13         4  3.555348          Dogecoin

# %%
pd.options.display.max_columns=100
train = pd.read_csv("../data/raw/train.csv")
train.head(10)
# Out:
#     timestamp  Asset_ID  Count          Open        High         Low  \
# 0  1514764860         2   40.0   2376.580000   2399.5000   2357.1400
# 1  1514764860         0    5.0      8.530000      8.5300      8.5300
# 2  1514764860         1  229.0  13835.194000  14013.8000  13666.1100
# 3  1514764860         5   32.0      7.659600      7.6596      7.6567
# 4  1514764860         7    5.0     25.920000     25.9200     25.8740
# 5  1514764860         6  173.0    738.302500    746.0000    732.5100
# 6  1514764860         9  167.0    225.330000    227.7800    222.9800
# 7  1514764860        11    7.0    329.090000    329.8800    329.0900
# 8  1514764920         2   53.0   2374.553333   2400.9000   2354.2000
# 9  1514764920         0    7.0      8.530000      8.5300      8.5145
#
#           Close       Volume          VWAP    Target
# 0   2374.590000    19.233005   2373.116392 -0.004218
# 1      8.530000    78.380000      8.530000 -0.014399
# ...

# %%
train['datetime'] = pd.to_datetime(train['timestamp'], unit='s')
train.tail(10)
# Out:
#            timestamp  Asset_ID   Count         Open         High          Low  \
# 24236796  1632182400         4   537.0     0.208622     0.208800     0.208200
# 24236797  1632182400         5   450.0     4.201240     4.203000     4.194000
# 24236798  1632182400         7   212.0    49.093300    49.123800    49.028000
# 24236799  1632182400         6  2205.0  2976.858333  2978.820000  2969.350000
# 24236800  1632182400         8    82.0     1.284250     1.303100     1.265200
# 24236801  1632182400         9   775.0   157.181571   157.250000   156.700000
# 24236802  1632182400        10    34.0  2437.065067  2438.000000  2430.226900
# 24236803  1632182400        13   380.0     0.091390     0.091527     0.091260
# 24236804  1632182400        12   177.0     0.282168     0.282438     0.281842
# 24236805  1632182400        11    48.0   232.695000   232.800000   232.240000
#
#                 Close        Volume         VWAP  Target   datetime
# ...

# %%
train.Target.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
train.Target.mean(), train.Target.std()
# Out:
# (7.121751598291133e-06, 0.0056790419769051)
